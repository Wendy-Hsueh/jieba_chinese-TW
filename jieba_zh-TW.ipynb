# %%
# Library
import jieba
import pandas as pd
import numpy as np
from collections import defaultdict
import os, io, re

# %%
# read file
df =  pd.read_csv('./data_20211014.csv', index_col = None, encoding = 'utf-8-sig')
df
# Out:
#                            title  \
# 0            [問卦] 所以8000億是紓到哪裡去了
# 1                   [問卦] 城中城會拆除嗎
# 2             [問卦] 如何克服在外拉屎只能乾擦？
# 3     Re: [問卦] 有沒有比提高基本工資更好的做法呢?
# 4         Re: [問卦] 台灣怎麼這麼愛拍電影甲片？
# ...                          ...
# 2336    Re: [問卦] 40年以上的大樓是不是該全拆了
# 2337         Re: [問卦] 摩斯是最盤的速食店嗎
# 2338                  [問卦] 禮拜五了啦
# 2339          [問卦] 台灣勞工奴性是不是都很堅強
# 2340          [問卦] 挖眼案跟割喉案那個比較衰小
#
#                                                 content              time
# 0     \n如題啦\n\n買了500萬然後剩一堆的疫苗\n\n然後補助八大行業？？？\n\n哇 一下...  2021/10/14 12:00
# 1     \n查了一下\n原來這不是第一次火災了\n這種火災過的建築物會拆除嗎?\n還是會繼續使用?\...  2021/10/14 12:00
# 2     \n如標題\n\n在外拉屎 真的很麻煩\n\n怎麼擦都擦不乾淨\n\n沒水可以沖沖\n\n五...  2021/10/14 12:00
# 3     \n※ 引述《thelittleone (thelittleone)》之銘言：\n: 女口是...  2021/10/14 12:00
# 4     \n※ 引述《DemonPomelo (淨化肥宅獨裁者)》之銘言：\n: 幹拎娘，台灣電影甲...  2021/10/14 12:01
# ...                                                 ...               ...
# 2336  \n看到這個真的笑死\n當年台北xx院都更\n一堆覺青去幫貪得無厭的釘子戶\n要更好的條件\...  2021/10/15 11:57
# 2337  \n最近嚐鮮新口味蜜芋紅豆珍珠堡，\n\n超級失望，官網照片是這個，\n\nhttps://...  2021/10/15 11:58
# 2338  \n\n今天又到了本肥最愛的禮拜五 話說\n大家五倍券花完了嗎？本肥想要買衣服\n有人有推薦...  2021/10/15 11:58
# 2339  \n如題我包恩\n\n\n\n像是外送員遇到買很多東西衛生紙的客人\n卻是上網罵說為什麼要買...  2021/10/15 11:59
# 2340  \n\n挖眼案\n\n店員只是提醒了客人一下就被毆打挖眼\n\n類似情況可以套用到各種第一線...  2021/10/15 11:59
#
# [2341 rows x 3 columns]

# %%
# read specified field
texts = list(df.content)
# calculate word frequency
frequency = defaultdict(int)
seg_list = [[],[],]
texts_list = []
stopWords = []
cnt = 0
# read dictionary and stopwords
jieba.load_userdict('D:/00研究所/LAB_PROJECT/03_分類平台/LDA_code/jieba_dict/userDict.txt')
with open('D:/00研究所/LAB_PROJECT/03_分類平台/LDA_code/jieba_dict/stopwords.txt', encoding = 'UTF-8') as f:
    stop_words = f.read().splitlines()
    stopWords.append(stop_words)
for text in texts:
    # remove english and numbers
    text = re.sub("[A-Za-z0-9\,\。]", "", text)
    if type(text) != float:
        texts_list.append(text)
for text in texts_list:
    text = jieba.cut(text, cut_all=False)
    for token in text:
        frequency[token]+=1
        if token in stopWords[0]:
            pass
        else:
            if len(token) >= 2 and frequency[token] >= 2 :
                seg_list[cnt].append(token)
                
            else:
                pass
       
    seg_list.append([])
    cnt+=1 

print(len(seg_list))
print(seg_list)
# Out:
# Building prefix dict from the default dictionary ...
# Loading model from cache C:\Users\User\AppData\Local\Temp\jieba.cache
# Loading model cost 0.844 seconds.
# Prefix dict has been built successfully.
# 2343
# [[], ['火災'], [], ['工資', '工資', '基層', '勞工', '工資', '基層', '勞工', '物價', '日本', '房價', '房子', '房價', '崩盤'], ['台灣', '甲片', '台灣', '台灣', '同性', '結婚', '塔綠班', '安樂', '安樂', '同性', '結婚', '台灣人', '準備', '安樂', '受惠', '同性', '結婚'], ['幫忙', '保護', '集合', '住宅', '火災', '逃生', '窗戶', '窗戶', '慢慢', '最好', '城中城', '警器', '房間', '火災', '警器', '高雄人', '求生', '平安'], ['希望', '最好', '小孩', '台灣', '教育', '印度', '種姓', '世代', '種姓', '還要', '小孩', '最低', '種姓', '最低', '種姓', '下來', '最低', '種姓', '最好', '還要', '生小孩'], ['作者', '標題', '時間', '標題', '半導體', '擴廠', '台積', '電用', '電量', '將占', '全台', '原文', '時間', '原文', '政策', '尖峰', '用電', '用電', '台積', '半導體', '擴廠', '估計', '台積', '全台', '用電', '零排放', '目標', '能源', '表示', '能源', '能源', '轉型', '比例', '再生能源', '發電', '發電', '目標', '經濟部', '表示', '因應', '降低', '燃煤', '發電', '主要', '天然', '再生能源', '發電', '增加', '燃氣', '機組', '增加', '裝置', '容量', '再生能源', '目標', '台積', '擴張', '學者', '電量', '成長', '啟源', '指出', '台灣', '能源', '教授', '台灣', '再生能源', '用電', '達淨', '零排放', '目標', '政府', '能源', '延役', '廖慧珠', '強調', '延役', '能源', '政策', '轉換', '之際', '台積', '電用', '電量', '將占', '全台', '核電廠', '指出', '指出', '地方', '論點', '矛盾', '列出', '論點', '態度', '攻擊', '攻擊'], ['主要', '分享', '分享', '台灣', '還要'], ['老舊', '城中城', '基隆', '城上城'], ['魔咒'], ['支撐', '胖子', '肌肉', '胖子'], ['中國', '中國', '台灣', '中國', '依賴', '台灣'], ['疫苗', '治療'], ['女口', '提高', '工資', '主要', '保護', '基層', '勞工', '勞工領', '薪水', '支撐', '生活', '板上', '對著', '政策', '怨聲', '工資', '時物價', '會漲', '高聲', '調高', '工資', '基層', '勞工', '死活', '執政黨', '放任', '物價', '比調', '工資', '方式', '保障', '基層', '勞工', '生計', '工資', '物價', '物價', '會漲', '工資', '勞工領', '工資', '工資', '台灣', '勞工', '工資', '工資', '工資', '工資', '外勞', '台灣'], ['做到', '最大', '事實'], ['城中城', '救出', '搜救', '死傷', '時間', '救出', '高雄市', '明昭', '表示', '目擊者', '火災', '因素'], ['徵求', '內容', '同事', '準備', '辦公室', '希望', '聯絡', '最大', '辦公室', '小貓', '完全', '超級'], ['我國', '我國', '年號'], ['高雄', '城中城', '惡火', '救出', '陳其邁', '排除', '因素', '高雄市', '陳其邁', '火警', '高雄市', '陳其邁', '內政部長', '徐國勇', '火警', '勘災', '高雄市', '城中城', '社區', '大火', '七點', '左右', '控制', '持續', '搜救', '內政部長', '徐國勇', '高雄市', '陳其邁', '火警', '勘災', '送醫', '生命', '跡象', '市府', '救援', '陳其邁', '建築物', '老舊', '陸續', '發現', '住戶', '疑似', '最好', '火警', '發生', '高雄市', '消防局', '疑似', '高雄', '啟動', '相關', '人員', '市長', '陳其邁', '火警', '原因', '排除', '因素'], ['記者', '數據', '高端', '疫苗', '表示', '疫苗', '期中', '分析', '數據', '呼吸', '醫學', '發表', '高端', '預期', '新冠', '肺炎', '疫苗', '高端', '表示', '試驗', '傳統', '臨床', '試驗', '高端', '台大', '醫師', '第一', '作者', '擔任', '作者', '臨床', '試驗', '中心', '研發', '論文', '期刊', '胳針', '呼吸', '醫學', '審查', '發表', '高端', '指出', '胳針', '呼吸', '醫學', '系統', '醫學', '期刊', '影響', '相關', '審查', '發表', '澳洲', '新冠', '肺炎', '疫苗', '試驗', '高端', '表示', '胳針', '呼吸', '醫學', '發布', '數據', '國際', '免疫', '生成', '澳洲', '學者', '發表', '疫苗', '保護力', '推估', '預期', '高端', '新冠', '肺炎', '疫苗', '保護力', '成區間', '高端', '期刊', '藉由', '統計', '方式', '高端', '新冠', '疫苗', '保護力', '藉由', '數據', '發布', '新冠', '肺炎', '疫苗', '免疫', '橋接', '參照', '基礎', '刪除', '連結', '期刊'], ['電熱毯', '肥肥', '東西', '主要', '傳統', '方式', '方式', '地方', '地方', '醫師', '第一'], ['基地', '公司', '台灣', '這套', '顯示', '速度'], ['建國路', '建國路'], ['文組', '工作', '覺青'], ['老人', '疫苗', '老人', '一間', '還要', '花博', '台灣', '地方'], ['公司', '阿姨', '社會', '生小孩', '慢慢', '下去', '台灣', '老人', '照顧', '需求', '成為', '老人家', '機器', '老人'], ['台積電', '停電', '台積', '停電', '台中', '大潭', '火力', '全面', '機組', '核能', '全面', '火力', '天然', '核能', '公投', '支持', '三接', '報告', '饅頭班長', '本文', '轉錄', '作者', '報告', '饅頭班長', '標題', '半導體', '擴廠', '台積', '電用', '電量', '將占', '全台', '時間', '原文', '標題', '半導體', '擴廠', '台積', '電用', '電量', '將占', '全台', '學者', '示警', '缺電達', '原文', '連結', '發布', '時間'], ['重要', '清楚', '同學', '大學', '同學', '公司', '同事', '同事', '國中', '同學', '大學', '同學', '公司', '女同事', '順便', '發現', '一點', '女同事', '一發', '所有', '七點', '晚餐', '小女孩', '打開', '女同事', '同事', '好好'], ['簡單', '小孩', '文盲', '居多', '阿祖', '節育', '還會', '晚上', '小孩', '工作', '大部分', '印度', '法律', '明文', '規定', '種姓', '制度', '拿掉', '印度', '特別', '種姓', '世代', '為奴', '世代', '最低', '種姓', '還要', '再生', '小孩', '受苦', '最低', '種姓', '說好', '最低', '種姓', '滅絕', '就會', '剩次', '然後次', '下來', '剩婆羅族', '最低', '種姓', '最好', '反抗', '還要', '老命', '生小孩'], ['官員', '鞠躬', '哈腰', '當總統', '元首', '獨裁者'], ['物價', '吵架', '政策', '眼神', '政府', '還在', '台灣'], ['時間'], ['大樓', '相關'], ['大學', '教授', '病人', '免費', '試驗', '這套', '治療', '幫忙', '垃圾', '薪水'], ['選國', '旅券', '農遊券', '國旅券', '選國', '旅券', '勾選', '農遊券', '農遊券', '選國', '旅券', '農遊券'], ['台灣', '弱勢', '所有 ...
